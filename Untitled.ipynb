# %%
import pandas as p
import numpy as n

# %%
data=p.read_csv('data/OPD-Under-5-years-2012.csv')

# %%
data
# Out:
#            Region  Malaria  Acute Respiratory Infection  Diarrhoeal Disease  \
# 0          Arusha    88100                       140656               41686
# 1   Dar es Salaam   385645                       162618              108668
# 2          Dodoma    96628                       123478               44150
# 3          Iringa    65197                       105096               36377
# 4          Kagera   220091                       133368               40876
# 5          Kigoma   235244                       110309               37748
# 6     Kilimanjaro   206942                       169335               37295
# 7           Lindi   182107                       103472               26335
# 8            Mara   337855                       119292              143524
# 9         Manyara   100352                        82676               44367
# 10          Mbeya   191570                       144125               80435
# ...

# %%
data.shape
# Out:
# (21, 32)

# %%
data.describe()
# Out:
#              Malaria  Acute Respiratory Infection  Diarrhoeal Disease  \
# count      21.000000                    21.000000           21.000000
# mean   231504.857143                125010.380952        62464.523810
# std    113484.127205                 44474.603485        49514.976403
# min     65197.000000                 38326.000000        19137.000000
# 25%    159224.000000                103472.000000        37295.000000
# 50%    206942.000000                123478.000000        42911.000000
# 75%    337855.000000                144125.000000        80435.000000
# max    453194.000000                219216.000000       230553.000000
#
#        Intestinal Worms      Pneumonia  Eye Infections  Ear Infections  \
# count         21.000000      21.000000       21.000000       21.000000
# mean       31938.809524   63800.904762    17143.761905    10271.428571
# std        26354.653951   33206.943733     6887.070668     6374.155454
# ...

# %%
for column in data.columns:
    print(column)
# Out:
# Region
# Malaria
# Acute Respiratory Infection
# Diarrhoeal Disease
# Intestinal Worms
# Pneumonia
# Eye Infections
# Ear Infections
# Skin Infections
# Bronchial Asthma
# Cardiovascular Diseases
# Sexually Transmitted diseases
# Urinary Tract Infections
# Anaemia
# Schistosomiasis
# Protein Energy Malnutrition
# Other Nutritional Disorders
# Epilepsy
# Burns
# Poisoning
# Minor surgical Conditions
# Tuberculosis
# HIV/AIDS
# Non-Infectious Skin Disease
# Vitamin A Def Xerophthalmia
# Non-Infectious Eye Dis (ukitoa Vitamin  A deficiency)
# Joint Disorders
# Dental Caries
# Other oral disorders
# Ill Defined Symptoms (No diagnosis)
# Others
# Total

# %%
X = data.drop('Region',axis = 1)
y = data.Region

# %%
X=p.get_dummies(X)

# %%
y
# Out:
# 0            Arusha
# 1     Dar es Salaam
# 2            Dodoma
# 3            Iringa
# 4            Kagera
# 5            Kigoma
# 6       Kilimanjaro
# 7             Lindi
# 8              Mara
# 9           Manyara
# 10            Mbeya
# 11         Morogoro
# 12           Mtwara
# 13          Mwanza
# 14            Total
# 15            Rukwa
# 16           Ruvuma
# 17          Singida
# 18        Shinyanga
# 19          Tabora
# 20           Tanga
# Name: Region, dtype: object

# %%
# Out:
#            Region  Malaria  Acute Respiratory Infection  Diarrhoeal Disease  \
# 0          Arusha    88100                       140656               41686
# 1   Dar es Salaam   385645                       162618              108668
# 2          Dodoma    96628                       123478               44150
# 3          Iringa    65197                       105096               36377
# 4          Kagera   220091                       133368               40876
# 5          Kigoma   235244                       110309               37748
# 6     Kilimanjaro   206942                       169335               37295
# 7           Lindi   182107                       103472               26335
# 8            Mara   337855                       119292              143524
# 9         Manyara   100352                        82676               44367
# 10          Mbeya   191570                       144125               80435
# ...

# %%
df=p.DataFrame(data)
df
# Out:
#            Region  Malaria  Acute Respiratory Infection  Diarrhoeal Disease  \
# 0          Arusha    88100                       140656               41686
# 1   Dar es Salaam   385645                       162618              108668
# 2          Dodoma    96628                       123478               44150
# 3          Iringa    65197                       105096               36377
# 4          Kagera   220091                       133368               40876
# 5          Kigoma   235244                       110309               37748
# 6     Kilimanjaro   206942                       169335               37295
# 7           Lindi   182107                       103472               26335
# 8            Mara   337855                       119292              143524
# 9         Manyara   100352                        82676               44367
# 10          Mbeya   191570                       144125               80435
# ...

# %%
def tran_mathscrore(x):
    if x=='Rukwa':
        return 1
    if x=='Tabora':
        return 2
df['Trans_MathScore']=df['MathScore'].apply(tran_mathscore)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anconda og\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MathScore'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-bb03d22dd2bc> in <module>
#       4     if x=='Tabora':
# ...
