# %% [markdown]
# # <img style="float: left; padding-right: 100px; width: 300px" src="images/logo.png">AI4SG Bootcamp:
#
#
# ## Supervised Machine Learning
# **Authors:** Frederick Apina
#
#
# ---

# %% [markdown]
# ## Intro to regression problem
# what, how does it work, application and how to evaluate

# %% [markdown]
# ## End to end ML

# %% [markdown]
# ## Apply end to end ML on a specific use-case : Predict age of mobile money user on zindi dataset.

# %% [markdown]
# *Problem*
#
# *Only 16.7% of the population in Tanzania has a bank account. But an additional 48.6% of Tanzanians who don’t have a bank account do have other types of formal financial services, primarily mobile money.*
#
# *For people who have been traditionally excluded from the formal financial system in Africa and other developing markets, mobile money has become an important entry point to financial inclusion. While mobile money is a tool for transferring money among people and businesses/other institutions, it is increasingly becoming a platform for people to access a broad range of financial services, including savings, credit, and insurance.*
#
# *The objective of this puse-case is to create a machine learning model to predict age of individuals who are most likely to use mobile money and other financial services (savings, credit, and insurance).
#
# *This model can help mobile money providers target new clients and markets across Tanzania more effectively, and also help financial services providers cross-sell other financial services (savings, credit, and insurance) to the existing mobile money customer base.*

# %% [markdown]
# **Code book for mobile money dataset**: Put a link to this code book
#
# ID <br>
# Unique respondent ID
# <String>
#
# Q1 - Age
# <Number>
#
# Q2 - gender <br>
# 1 Male
# 2 Female
#
# Q3 - Marital status <br>
# 1 Married
# 2 Divorced
# 3 Widowed
# 4 Single/never married
#
# Q4 - Highest level of education completed? <br>
# 1 No formal education
# 2 Some primary
# 3 Primary completed
# 4 Post primary technical training
# 5 Some secondary
# 6 University or other higher education
# 7 Don’t know
#
# Q5 - Which of the following applies to you? Read out; Single response <br>
# 1 You personally own the land/plot where you live
# 2 You own the land/plot together with someone else
# 3 A household member owns the land/plot
# 4 The land/plot is rented
# 5 You don’t own or rent the land
# 6 Don’t know
#
# Q6 - Do you personally own land (other than the land you live on) that you have land certificates of ownership for? <br>
# 1 Yes
# 2 No
#
# Q7 - Do you personally own a mobile phone? <br>
# 1 Yes
# 2 No
#
# Q8_1 through Q8_11 - Different people have different ways of getting money, please tell me how you get the money you spend?
# Multiple mention possible
#
# Q8_1 - Salaries/wages <br>
# 1 Yes
# 0 No
#
# Q8_2 - Money from trading/selling   Anything you produce/grow/raise/make/collect with the intention of selling <br>
# 1 Yes
# 0 No
#
# Q8_3 - Money from providing a service – i.e. such as transport, hairdressing, processing, hospitality services (food & accommodation) <br>
# 1 Yes
# 0 No
#
# Q8_4 - Piece work/Casual labor/Occasional jobs <br>
# 1 Yes
# 0 No
#
# Q8_5 - Rental income <br>
# 1 Yes
# 0 No
#
# Q8_6 - Interest from savings, investments, stocks, unit trusts etc. <br>
# 1 Yes
# 0 No
#
# Q8_7 - Pension <br>
# 1 Yes
# 0 No
#
# Q8_8 - Social welfare money/grant from Government <br>
# 1 Yes
# 0 No
#
# Q8_9 - Rely on someone else/others to give/send me money <br>
# 1 Yes
# 0 No
#
# Q8_10 - Don’t get money – someone else pays my expenses <br>
# 1 Yes
# 0 No
#
# Q8_11 - Other <br>
# 1 Yes
# 0 No
#
# Q9 - Only for those who said they get a salary/wages. Who do you work for?  <br>
# -1 not applicable
# 1 Government
# 2 Private company/business
# 3 Individual who owns his own business
# 4 Small scale farmer
# 5 Commercial farmer
# 6 Work for individual/household e.g. security guard, maid etc.
# 7 Other
#
# Q10 - Only for those who said they get money from selling things – what kind of things do you MAINLY sell (get most money from)? <br>
# -1 not applicable
# 1 Crops/produce I grow
# 2 Products I get from livestock
# 3 Livestock
# 4 Fish you catch yourself/aquaculture
# 5 Things you buy from others – agricultural products
# 6 Things you buy from others – non-agricultural products
# 7 Things you make (clothes, art, crafts)
# 8 Things you collect from nature (stones, sand, thatch, herbs)
# 9 Things you process (honey, dairy products, flour)
# 10 Other
#
# Q11 - Only for those who said they get money from providing a service – what kind of services do you MAINLY provide (get most money from)? <br>
# -1 not applicable
# 1 Personal services (hairdressers, massage, etc.)
# 2 Telecommunications/IT
# 3 Financial services
# 4 Transport
# 5 Hospitality – Accommodation, restaurants, etc.
# 6 Information/research
# 7 Technical – mechanic, etc.
# 8 Educational/child care
# 9 Health services – traditional healer etc.
# 10 Legal services
# 11 Security
# 12 Other, specify
#
# Q12 - In the past 12 months, have you sent money to someone in a different place within the country or outside of Tanzania? <br>
# 1 Yes
# 2 No
#
# Q13 - When did you last send money? <br>
# -1 not applicable
# 1 Yesterday/today
# 2 In the past 7 days
# 3 In the past 30 days
# 4 In the past 90 days
# 5 More than 90 days ago but less than 6 months ago
# 6 6 months or longer ago
#
# Q14 - In the past 12 months, have you received money from someone in a different place within the country or from outside the country? <br>
# 1 Yes
# 2 No
#
# Q15 - When did you last receive money? <br>
# -1 not applicable
# 1 Yesterday/today
# 2 In the past 7 days
# 3 In the past 30 days
# 4 In the past 90 days
# 5 More than 90 days ago but less than 6 months ago
# 6 6 months or longer ago
#
# Q16 - In the past 12 months, how often did you use mobile money for purchases of goods and/or services?
# -1 not applicable <br>
# 1 Never
# 2 Daily
# 3 Weekly
# 4 Monthly
# 5 Less often than monthly
#
# Q17 - In the past 12 months, how often did you use mobile money for paying your bills? <br>
# -1 not applicable
# 1 Never
# 2 Daily
# 3 Weekly
# 4 Monthly
# 5 Less often than monthly
#
# Q18 - Literacy in Kiswhahili <br>
# 1 Can read and write
# 2 Can read only
# 3 Can write only
# 4 Can neither read nor write
# 5 Refused to read
#
# Q19 - Literacy in English <br>
# 1 Can read and write
# 2 Can read only
# 3 Can write only
# 4 Can neither read nor write
# 5 Refused to read
#
# Latitude - Approximate latitude <br>
# Number
#
# Longitude - Approximate longitude <br>
# Number
#
# Mobile_money_classification <br>
# 0 no mobile money and no other financial service (saving, borrowing, insurance)
# 1 no mobile money, but at least one other financial service
# 2 mobile money only
# 3 mobile money and at least one other financial service

# %% [markdown]
# # Setup

# %% [markdown]
# import important modules

# %%
import numpy as np
np.random.seed(42)#for reproducible experiments
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# Where to save the figures
FIGURE_FOLDER = "figures"
IMAGES_PATH = os.path.join("images", FIGURE_FOLDER)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ### Get the data

# %%
DATA_PATH = "data/"

# %%
def load_data(data_path=DATA_PATH):
    csv_path = os.path.join(data_path, "train_data.csv")
    return pd.read_csv(csv_path)

# %%
data = load_data()
data.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q13  Q14  Q15  Q16  Q17  \
# 0  5423  49   2   1   6   1   2   1     0     1  ...    1    1    3    1   -1
# 1  7314  18   2   4   6   3   2   2     0     0  ...   -1    2   -1    1   -1
# 2  4320  17   2   1   3   3   2   2     0     0  ...   -1    2   -1    1   -1
# 3  7625  37   2   1   3   1   2   1     0     1  ...   -1    2   -1    1   -1
# 4  9183  30   2   2   3   1   2   2     0     1  ...   -1    2   -1    5   -1
#
#    Q18  Q19  Latitude  Longitude  mobile_money_classification
# 0    1    2 -8.103924  35.902981                            3
# 1    1    4 -5.934199  37.278615                            0
# 2    1    4 -4.663185  38.471053                            1
# 3    4    4 -7.955359  36.863508                            1
# 4    1    4 -5.016777  32.810082                            2
#
# [5 rows x 33 columns]

# %%
data
# Out:
#         ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q13  Q14  Q15  Q16  \
# 0     5423  49   2   1   6   1   2   1     0     1  ...    1    1    3    1
# 1     7314  18   2   4   6   3   2   2     0     0  ...   -1    2   -1    1
# 2     4320  17   2   1   3   3   2   2     0     0  ...   -1    2   -1    1
# 3     7625  37   2   1   3   1   2   1     0     1  ...   -1    2   -1    1
# 4     9183  30   2   2   3   1   2   2     0     1  ...   -1    2   -1    5
# 5     6549  34   2   4   5   5   2   1     0     1  ...    4    1    1    1
# 6     6407  34   2   1   3   3   2   1     0     0  ...   -1    1    3    4
# 7     8253  27   2   1   3   5   2   1     0     1  ...   -1    1    3    1
# 8     6512  32   2   1   6   5   2   1     0     0  ...   -1    1    4    1
# 9     1277  46   1   1   3   1   1   2     0     0  ...   -1    1    5    1
# 10    6063  30   2   1   1   3   2   2     0     1  ...   -1    2   -1    1
# 11     435  22   1   4   6   5   2   1     0     0  ...   -1    2   -1    3
# 12     275  19   2   1   3   5   2   1     0     0  ...   -1    2   -1    1
# 13     476  56   1   3   3   4   2   1     1     0  ...   -1    2   -1    5
# 14    5038  30   2   2   3   4   2   1     0     1  ...   -1    2   -1    1
# 15    2571  34   2   1   6   5   1   1     0     0  ...   -1    2   -1    1
# 16    6745  65   2   3   1   1   2   2     0     0  ...   -1    2   -1    1
# 17     924  37   2   1   3   4   1   1     0     1  ...    1    1    3    1
# 18    1349  37   1   1   3   1   1   2     0     0  ...   -1    2   -1    1
# 19    4026  21   1   4   2   5   2   2     0     1  ...   -1    2   -1    1
# 20    2134  51   2   1   3   3   2   1     0     0  ...    5    2   -1    1
# 21    4273  40   2   3   2   1   2   2     0     0  ...    5    2   -1    1
# 22    2823  49   1   1   2   1   2   1     0     1  ...    4    2   -1    1
# 23    2490  21   1   1   2   1   2   1     0     1  ...   -1    2   -1    1
# 24    3557  37   2   1   6   1   2   1     0     1  ...    3    1    3    1
# 25    5903  32   2   1   2   1   2   2     0     1  ...   -1    2   -1    1
# 26    2398  45   2   1   1   3   2   1     0     0  ...   -1    1    2    5
# 27    5192  53   2   1   7   1   1   1     1     0  ...   -1    2   -1    1
# 28    4425  35   1   1   3   1   1   2     0     1  ...   -1    2   -1    1
# 29    6108  44   2   1   3   3   2   2     0     1  ...   -1    2   -1    1
# ...    ...  ..  ..  ..  ..  ..  ..  ..   ...   ...  ...  ...  ...  ...  ...
# 5893  5189  43   1   1   3   1   2   1     0     1  ...    4    2   -1    5
# 5894  9198  25   2   1   3   1   2   1     0     1  ...   -1    2   -1    1
# 5895  4138  30   2   1   3   3   2   1     0     0  ...   -1    2   -1    1
# 5896  1389  20   1   4   6   4   2   1     0     1  ...    3    2   -1    1
# 5897  2576  70   2   2   1   3   2   2     0     0  ...   -1    2   -1    1
# 5898  2821  26   1   1   3   4   2   2     0     1  ...    5    1    4    1
# 5899  2351  19   2   1   3   4   2   2     0     1  ...   -1    2   -1    1
# 5900   807  54   1   1   3   1   1   1     0     0  ...   -1    1    4    1
# 5901  5853  37   2   1   3   3   2   1     0     1  ...    5    1    5    1
# 5902  3302  36   2   1   3   3   2   2     0     1  ...   -1    2   -1    1
# 5903  3579  52   2   1   3   3   2   1     0     0  ...   -1    1    6    1
# 5904  5918  33   1   2   3   1   2   2     0     1  ...    5    2   -1    5
# 5905  1250  30   2   1   1   1   2   2     0     1  ...   -1    1    2    5
# 5906   403  35   1   1   6   1   1   1     0     0  ...    2    1    1    3
# 5907  3081  54   1   1   3   1   2   1     0     1  ...    2    1    1    2
# 5908  5085  67   2   2   3   2   2   2     0     0  ...   -1    2   -1    1
# 5909  3924  45   2   4   2   1   1   1     0     1  ...   -1    2   -1    1
# 5910  9104  65   2   3   1   1   2   2     0     1  ...   -1    2   -1    1
# 5911  4366  35   2   1   3   3   1   2     0     1  ...   -1    2   -1    1
# 5912   475  25   2   4   6   5   2   1     0     0  ...    2    2   -1    4
# 5913  2302  43   2   1   2   1   2   2     0     1  ...   -1    2   -1    1
# 5914  6075  61   2   3   3   1   1   2     0     1  ...   -1    2   -1    1
# 5915  5837  35   1   1   1   1   2   1     0     1  ...   -1    2   -1    1
# 5916   491  40   2   1   3   1   1   1     0     1  ...    5    1    4    1
# 5917  7469  47   1   1   3   1   1   2     0     1  ...   -1    2   -1    1
# 5918  9324  27   1   4   3   5   2   1     0     1  ...    2    1    5    4
# 5919    65  30   1   1   6   5   2   1     0     0  ...    3    1    3    1
# 5920  7712  56   2   3   1   1   2   1     0     1  ...   -1    1    2    1
# 5921  5830  60   2   3   1   3   2   2     0     1  ...   -1    2   -1    1
# 5922  9012  47   1   2   3   1   2   2     0     1  ...    6    2   -1    1
#
#       Q17  Q18  Q19   Latitude  Longitude  mobile_money_classification
# 0      -1    1    2  -8.103924  35.902981                            3
# 1      -1    1    4  -5.934199  37.278615                            0
# 2      -1    1    4  -4.663185  38.471053                            1
# 3      -1    4    4  -7.955359  36.863508                            1
# 4      -1    1    4  -5.016777  32.810082                            2
# 5       1    1    2  -5.714379  34.496400                            3
# 6       4    1    4  -3.667719  35.602861                            3
# 7      -1    4    4 -10.904329  38.299342                            1
# 8      -1    1    1  -6.090759  39.423515                            3
# 9      -1    1    4  -9.478925  34.649126                            2
# 10     -1    4    4  -8.539498  32.943786                            1
# 11     -1    1    1  -2.490701  32.911952                            2
# 12     -1    1    1  -2.502020  32.888400                            3
# 13     -1    1    4  -7.954386  31.607171                            2
# 14      1    1    4  -1.324505  31.791353                            3
# 15     -1    1    4  -2.611118  32.071376                            2
# 16     -1    2    4  -1.941336  32.862624                            1
# 17     -1    1    1  -3.366172  36.727774                            3
# 18     -1    1    4  -2.635849  33.971986                            1
# 19     -1    1    4  -9.910488  38.995033                            1
# 20     -1    4    4  -2.416812  32.935347                            2
# 21     -1    1    1  -3.076902  32.087078                            1
# 22     -1    4    4  -7.679892  31.562680                            2
# 23     -1    4    4  -3.042382  31.377918                            1
# 24     -1    1    1  -7.752970  35.482497                            3
# 25     -1    1    4 -10.951107  39.026784                            1
# 26     -1    4    5  -7.750790  35.864397                            3
# 27      1    1    1  -6.165909  39.193836                            3
# 28     -1    4    4  -9.246992  34.775729                            1
# 29     -1    1    4  -3.239878  33.447817                            0
# ...   ...  ...  ...        ...        ...                          ...
# 5893   -1    1    4  -4.460195  29.808280                            3
# 5894   -1    1    4 -10.519213  38.678534                            0
# 5895   -1    1    4  -3.749702  33.126838                            1
# 5896    1    1    1  -7.783946  35.712325                            3
# 5897   -1    4    4  -7.119389  37.803670                            0
# 5898   -1    1    2  -7.680544  31.562424                            2
# 5899   -1    5    4  -4.576166  30.092778                            0
# 5900    1    1    1  -2.877865  32.247133                            3
# 5901   -1    1    4  -2.283778  32.260851                            3
# 5902   -1    1    4 -11.023280  35.123918                            1
# 5903    4    1    4  -4.794421  38.285624                            2
# 5904   -1    1    4  -9.435014  33.945591                            3
# 5905   -1    4    4  -9.764505  39.620431                            2
# 5906    5    1    1  -6.200187  39.253985                            3
# 5907    3    1    1  -6.165492  35.893101                            3
# 5908   -1    1    2  -5.968190  39.195878                            1
# 5909   -1    2    4  -2.776980  32.703537                            1
# 5910   -1    4    4  -2.805099  33.985627                            0
# 5911   -1    4    4  -4.000029  34.543006                            1
# 5912   -1    1    4  -7.730373  35.719675                            2
# 5913   -1    1    4  -8.797850  34.235875                            0
# 5914   -1    1    4  -8.536913  32.941265                            1
# 5915   -1    4    4 -11.014758  39.443339                            2
# 5916    1    1    4  -7.954609  31.607382                            3
# 5917   -1    1    2 -11.144555  37.512141                            0
# 5918   -1    1    4  -7.913354  39.674241                            3
# 5919    4    1    4  -6.616494  39.110447                            3
# 5920    1    4    4  -1.591905  31.142165                            3
# 5921   -1    4    4  -7.045480  39.030732                            0
# 5922   -1    1    2  -2.120816  33.491314                            3
#
# [5923 rows x 33 columns]

# %%
data
# Out:
#         ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q13  Q14  Q15  Q16  \
# 0     5423  49   2   1   6   1   2   1     0     1  ...    1    1    3    1
# 1     7314  18   2   4   6   3   2   2     0     0  ...   -1    2   -1    1
# 2     4320  17   2   1   3   3   2   2     0     0  ...   -1    2   -1    1
# 3     7625  37   2   1   3   1   2   1     0     1  ...   -1    2   -1    1
# 4     9183  30   2   2   3   1   2   2     0     1  ...   -1    2   -1    5
# 5     6549  34   2   4   5   5   2   1     0     1  ...    4    1    1    1
# 6     6407  34   2   1   3   3   2   1     0     0  ...   -1    1    3    4
# 7     8253  27   2   1   3   5   2   1     0     1  ...   -1    1    3    1
# 8     6512  32   2   1   6   5   2   1     0     0  ...   -1    1    4    1
# 9     1277  46   1   1   3   1   1   2     0     0  ...   -1    1    5    1
# 10    6063  30   2   1   1   3   2   2     0     1  ...   -1    2   -1    1
# 11     435  22   1   4   6   5   2   1     0     0  ...   -1    2   -1    3
# 12     275  19   2   1   3   5   2   1     0     0  ...   -1    2   -1    1
# 13     476  56   1   3   3   4   2   1     1     0  ...   -1    2   -1    5
# 14    5038  30   2   2   3   4   2   1     0     1  ...   -1    2   -1    1
# 15    2571  34   2   1   6   5   1   1     0     0  ...   -1    2   -1    1
# 16    6745  65   2   3   1   1   2   2     0     0  ...   -1    2   -1    1
# 17     924  37   2   1   3   4   1   1     0     1  ...    1    1    3    1
# 18    1349  37   1   1   3   1   1   2     0     0  ...   -1    2   -1    1
# 19    4026  21   1   4   2   5   2   2     0     1  ...   -1    2   -1    1
# 20    2134  51   2   1   3   3   2   1     0     0  ...    5    2   -1    1
# 21    4273  40   2   3   2   1   2   2     0     0  ...    5    2   -1    1
# 22    2823  49   1   1   2   1   2   1     0     1  ...    4    2   -1    1
# 23    2490  21   1   1   2   1   2   1     0     1  ...   -1    2   -1    1
# 24    3557  37   2   1   6   1   2   1     0     1  ...    3    1    3    1
# 25    5903  32   2   1   2   1   2   2     0     1  ...   -1    2   -1    1
# 26    2398  45   2   1   1   3   2   1     0     0  ...   -1    1    2    5
# 27    5192  53   2   1   7   1   1   1     1     0  ...   -1    2   -1    1
# 28    4425  35   1   1   3   1   1   2     0     1  ...   -1    2   -1    1
# 29    6108  44   2   1   3   3   2   2     0     1  ...   -1    2   -1    1
# ...    ...  ..  ..  ..  ..  ..  ..  ..   ...   ...  ...  ...  ...  ...  ...
# 5893  5189  43   1   1   3   1   2   1     0     1  ...    4    2   -1    5
# 5894  9198  25   2   1   3   1   2   1     0     1  ...   -1    2   -1    1
# 5895  4138  30   2   1   3   3   2   1     0     0  ...   -1    2   -1    1
# 5896  1389  20   1   4   6   4   2   1     0     1  ...    3    2   -1    1
# 5897  2576  70   2   2   1   3   2   2     0     0  ...   -1    2   -1    1
# 5898  2821  26   1   1   3   4   2   2     0     1  ...    5    1    4    1
# 5899  2351  19   2   1   3   4   2   2     0     1  ...   -1    2   -1    1
# 5900   807  54   1   1   3   1   1   1     0     0  ...   -1    1    4    1
# 5901  5853  37   2   1   3   3   2   1     0     1  ...    5    1    5    1
# 5902  3302  36   2   1   3   3   2   2     0     1  ...   -1    2   -1    1
# 5903  3579  52   2   1   3   3   2   1     0     0  ...   -1    1    6    1
# 5904  5918  33   1   2   3   1   2   2     0     1  ...    5    2   -1    5
# 5905  1250  30   2   1   1   1   2   2     0     1  ...   -1    1    2    5
# 5906   403  35   1   1   6   1   1   1     0     0  ...    2    1    1    3
# 5907  3081  54   1   1   3   1   2   1     0     1  ...    2    1    1    2
# 5908  5085  67   2   2   3   2   2   2     0     0  ...   -1    2   -1    1
# 5909  3924  45   2   4   2   1   1   1     0     1  ...   -1    2   -1    1
# 5910  9104  65   2   3   1   1   2   2     0     1  ...   -1    2   -1    1
# 5911  4366  35   2   1   3   3   1   2     0     1  ...   -1    2   -1    1
# 5912   475  25   2   4   6   5   2   1     0     0  ...    2    2   -1    4
# 5913  2302  43   2   1   2   1   2   2     0     1  ...   -1    2   -1    1
# 5914  6075  61   2   3   3   1   1   2     0     1  ...   -1    2   -1    1
# 5915  5837  35   1   1   1   1   2   1     0     1  ...   -1    2   -1    1
# 5916   491  40   2   1   3   1   1   1     0     1  ...    5    1    4    1
# 5917  7469  47   1   1   3   1   1   2     0     1  ...   -1    2   -1    1
# 5918  9324  27   1   4   3   5   2   1     0     1  ...    2    1    5    4
# 5919    65  30   1   1   6   5   2   1     0     0  ...    3    1    3    1
# 5920  7712  56   2   3   1   1   2   1     0     1  ...   -1    1    2    1
# 5921  5830  60   2   3   1   3   2   2     0     1  ...   -1    2   -1    1
# 5922  9012  47   1   2   3   1   2   2     0     1  ...    6    2   -1    1
#
#       Q17  Q18  Q19   Latitude  Longitude  mobile_money_classification
# 0      -1    1    2  -8.103924  35.902981                            3
# 1      -1    1    4  -5.934199  37.278615                            0
# 2      -1    1    4  -4.663185  38.471053                            1
# 3      -1    4    4  -7.955359  36.863508                            1
# 4      -1    1    4  -5.016777  32.810082                            2
# 5       1    1    2  -5.714379  34.496400                            3
# 6       4    1    4  -3.667719  35.602861                            3
# 7      -1    4    4 -10.904329  38.299342                            1
# 8      -1    1    1  -6.090759  39.423515                            3
# 9      -1    1    4  -9.478925  34.649126                            2
# 10     -1    4    4  -8.539498  32.943786                            1
# 11     -1    1    1  -2.490701  32.911952                            2
# 12     -1    1    1  -2.502020  32.888400                            3
# 13     -1    1    4  -7.954386  31.607171                            2
# 14      1    1    4  -1.324505  31.791353                            3
# 15     -1    1    4  -2.611118  32.071376                            2
# 16     -1    2    4  -1.941336  32.862624                            1
# 17     -1    1    1  -3.366172  36.727774                            3
# 18     -1    1    4  -2.635849  33.971986                            1
# 19     -1    1    4  -9.910488  38.995033                            1
# 20     -1    4    4  -2.416812  32.935347                            2
# 21     -1    1    1  -3.076902  32.087078                            1
# 22     -1    4    4  -7.679892  31.562680                            2
# 23     -1    4    4  -3.042382  31.377918                            1
# 24     -1    1    1  -7.752970  35.482497                            3
# 25     -1    1    4 -10.951107  39.026784                            1
# 26     -1    4    5  -7.750790  35.864397                            3
# 27      1    1    1  -6.165909  39.193836                            3
# 28     -1    4    4  -9.246992  34.775729                            1
# 29     -1    1    4  -3.239878  33.447817                            0
# ...   ...  ...  ...        ...        ...                          ...
# 5893   -1    1    4  -4.460195  29.808280                            3
# 5894   -1    1    4 -10.519213  38.678534                            0
# 5895   -1    1    4  -3.749702  33.126838                            1
# 5896    1    1    1  -7.783946  35.712325                            3
# 5897   -1    4    4  -7.119389  37.803670                            0
# 5898   -1    1    2  -7.680544  31.562424                            2
# 5899   -1    5    4  -4.576166  30.092778                            0
# 5900    1    1    1  -2.877865  32.247133                            3
# 5901   -1    1    4  -2.283778  32.260851                            3
# 5902   -1    1    4 -11.023280  35.123918                            1
# 5903    4    1    4  -4.794421  38.285624                            2
# 5904   -1    1    4  -9.435014  33.945591                            3
# 5905   -1    4    4  -9.764505  39.620431                            2
# 5906    5    1    1  -6.200187  39.253985                            3
# 5907    3    1    1  -6.165492  35.893101                            3
# 5908   -1    1    2  -5.968190  39.195878                            1
# 5909   -1    2    4  -2.776980  32.703537                            1
# 5910   -1    4    4  -2.805099  33.985627                            0
# 5911   -1    4    4  -4.000029  34.543006                            1
# 5912   -1    1    4  -7.730373  35.719675                            2
# 5913   -1    1    4  -8.797850  34.235875                            0
# 5914   -1    1    4  -8.536913  32.941265                            1
# 5915   -1    4    4 -11.014758  39.443339                            2
# 5916    1    1    4  -7.954609  31.607382                            3
# 5917   -1    1    2 -11.144555  37.512141                            0
# 5918   -1    1    4  -7.913354  39.674241                            3
# 5919    4    1    4  -6.616494  39.110447                            3
# 5920    1    4    4  -1.591905  31.142165                            3
# 5921   -1    4    4  -7.045480  39.030732                            0
# 5922   -1    1    2  -2.120816  33.491314                            3
#
# [5923 rows x 33 columns]

# %%
data[['Latitude','Longitude']]
# Out:
#        Latitude  Longitude
# 0     -8.103924  35.902981
# 1     -5.934199  37.278615
# 2     -4.663185  38.471053
# 3     -7.955359  36.863508
# 4     -5.016777  32.810082
# 5     -5.714379  34.496400
# 6     -3.667719  35.602861
# 7    -10.904329  38.299342
# 8     -6.090759  39.423515
# 9     -9.478925  34.649126
# 10    -8.539498  32.943786
# 11    -2.490701  32.911952
# 12    -2.502020  32.888400
# 13    -7.954386  31.607171
# 14    -1.324505  31.791353
# 15    -2.611118  32.071376
# 16    -1.941336  32.862624
# 17    -3.366172  36.727774
# 18    -2.635849  33.971986
# 19    -9.910488  38.995033
# 20    -2.416812  32.935347
# 21    -3.076902  32.087078
# 22    -7.679892  31.562680
# 23    -3.042382  31.377918
# 24    -7.752970  35.482497
# 25   -10.951107  39.026784
# 26    -7.750790  35.864397
# 27    -6.165909  39.193836
# 28    -9.246992  34.775729
# 29    -3.239878  33.447817
# ...         ...        ...
# 5893  -4.460195  29.808280
# 5894 -10.519213  38.678534
# 5895  -3.749702  33.126838
# 5896  -7.783946  35.712325
# 5897  -7.119389  37.803670
# 5898  -7.680544  31.562424
# 5899  -4.576166  30.092778
# 5900  -2.877865  32.247133
# 5901  -2.283778  32.260851
# 5902 -11.023280  35.123918
# 5903  -4.794421  38.285624
# 5904  -9.435014  33.945591
# 5905  -9.764505  39.620431
# 5906  -6.200187  39.253985
# 5907  -6.165492  35.893101
# 5908  -5.968190  39.195878
# 5909  -2.776980  32.703537
# 5910  -2.805099  33.985627
# 5911  -4.000029  34.543006
# 5912  -7.730373  35.719675
# 5913  -8.797850  34.235875
# 5914  -8.536913  32.941265
# 5915 -11.014758  39.443339
# 5916  -7.954609  31.607382
# 5917 -11.144555  37.512141
# 5918  -7.913354  39.674241
# 5919  -6.616494  39.110447
# 5920  -1.591905  31.142165
# 5921  -7.045480  39.030732
# 5922  -2.120816  33.491314
#
# [5923 rows x 2 columns]

# %% [markdown]
# ### Discover and visualize the data to gain insights

# %%
data.shape
# Out:
# (5923, 33)

# %% [markdown]
# ### Check for missing values

# %%
total = data.isnull().sum().sort_values(ascending = False)
percent = round(data.isnull().sum().sort_values(ascending = False)/len(data)*100, 2)
missing_column=pd.concat([total, percent], axis = 1,keys= ['Total', 'Percent']) 
missing_column
# Out:
#                              Total  Percent
# mobile_money_classification      0      0.0
# Q8_8                             0      0.0
# Q1                               0      0.0
# Q2                               0      0.0
# Q3                               0      0.0
# Q4                               0      0.0
# Q5                               0      0.0
# Q6                               0      0.0
# Q7                               0      0.0
# Q8_1                             0      0.0
# Q8_2                             0      0.0
# Q8_3                             0      0.0
# Q8_4                             0      0.0
# Q8_5                             0      0.0
# Q8_6                             0      0.0
# Q8_7                             0      0.0
# Q8_9                             0      0.0
# Longitude                        0      0.0
# Q8_10                            0      0.0
# Q8_11                            0      0.0
# Q9                               0      0.0
# Q10                              0      0.0
# Q11                              0      0.0
# Q12                              0      0.0
# Q13                              0      0.0
# Q14                              0      0.0
# Q15                              0      0.0
# Q16                              0      0.0
# Q17                              0      0.0
# Q18                              0      0.0
# Q19                              0      0.0
# Latitude                         0      0.0
# ID                               0      0.0

# %%
data["mobile_money_classification"].value_counts()
# Out:
# 3    2600
# 1    1497
# 0    1159
# 2     667
# Name: mobile_money_classification, dtype: int64

# %% [markdown]
# ### Target Distribution

# %%
fig, ax = plt.subplots(ncols=1, figsize=(8,5))
ax=sns.kdeplot(data['Q1'])
ax.set(ylabel="Density", xlabel="Age", title="Age distribution")
save_fig("age_distribution")
# Out:
# Saving figure age_distribution

# %% [markdown]
# Question: What does this tell us? How can we center the distribution

# %% [markdown]
# Age distribution is skwed to the left with most people between 20 and 40.

# %%
#Apply log
fig, ax = plt.subplots(ncols=1, figsize=(8,5))
ax=sns.kdeplot(np.log1p(data['Q1']))
ax.set(ylabel="Density", xlabel="Age", title="Age distribution");

# %%
target=data['Q1']
data= data.drop(['Q1'],axis=1)

# %% [markdown]
# ### Explore features

# %%
data.dtypes.value_counts().sort_values().plot(kind='barh')
plt.title('Number of columns distributed by Data Types')
plt.xlabel('Number of columns')
plt.ylabel('Data type');
plt.savefig("images/figures/data_distribution.pdf", dpi=600)

# %%
numeric_column=data.select_dtypes(include=['float64']).columns
categ_column=data.select_dtypes(include=['int64']).columns

# %% [markdown]
# Let us see how many categorical features:

# %%
category_num=data[categ_column].apply(pd.Series.nunique, axis = 0).sort_values(ascending = False)
category_num=pd.concat([category_num], axis = 1,keys= ['Total']) 
category_num
# Out:
#                              Total
# ID                            5923
# Q10                             11
# Q11                              9
# Q4                               8
# Q15                              7
# Q13                              7
# Q9                               7
# Q17                              6
# Q5                               6
# Q19                              5
# Q18                              5
# Q16                              5
# Q3                               4
# mobile_money_classification      4
# Q8_9                             2
# Q8_10                            2
# Q8_7                             2
# Q8_6                             2
# Q8_5                             2
# Q8_4                             2
# Q8_3                             2
# Q8_2                             2
# Q8_1                             2
# Q7                               2
# Q6                               2
# Q8_11                            2
# Q12                              2
# Q14                              2
# Q2                               2
# Q8_8                             2

# %% [markdown]
# Questions: How should we handle categorical data

# %% [markdown]
# We will have to encode the columns having  2 categories and one-hot encode columns with more than 2 categories data. However the column with several categorical data need special attention.

# %%
more_category_columns = category_num[category_num["Total"]>50].index
more_category_columns
# Out:
# Index(['ID'], dtype='object')

# %% [markdown]
# The columns ID with very less unique data for each of their categories. We will drop this column

# %%
#Activity
data.drop(['ID'], axis=1, inplace=True)

# %%
from IPython import display
categ_column=data.select_dtypes(include=['int64']).columns
for column in categ_column:
    data[column].value_counts().sort_values().plot(kind='barh');
    plt.title(f"{column} Distribution")
    plt.show()
    
    input("Press Enter to continue...")
    display.clear_output()

# %%
from IPython import display
categ_column=data.select_dtypes(include=['int64']).columns
for column in categ_column:
    data[column].value_counts().sort_values().plot(kind='barh');
    plt.title(f"{column} Distribution")
    plt.show()
    
    input("Press Enter to continue...")
    display.clear_output()

# %% [markdown]
# Questions: what does these figure tell us. What conclusion can you make for each categorical feature

# %% [markdown]
#  Activity:  write a function to encode these categrorical feature

# %% [markdown]
# #  numerical features

# %%
data

# %%
numeric_column

# %%
for column in numeric_column:
    fig, ax = plt.subplots(ncols=1, figsize=(8,5))
    ax=sns.kdeplot(data[column])
    ax.set(ylabel="Density", xlabel=column, title=f"{column} distribution");
    plt.show()
    input("Press Enter to continue...")
    display.clear_output()

# %%
sns.scatterplot(x='Longitude', y='Latitude', data=data)

# %% [markdown]
# Question: what can we conclude about this plot

# %% [markdown]
# Scatter plot with age

# %%
sns.scatterplot(x='Longitude', y='Latitude', hue=target,  data=data)
save_fig("age_scatterplot")
# Out:
# Saving figure age_scatterplot

# %%
data["mobile_money_classification"].value_counts() / len(data)
# Out:
# 3    0.438967
# 1    0.252744
# 0    0.195678
# 2    0.112612
# Name: mobile_money_classification, dtype: float64

# %% [markdown]
# The argument `sharex=False` fixes a display bug (the x-axis values and legend were not displayed). This is a temporary fix (see: https://github.com/pandas-dev/pandas/issues/10611). Thanks to Wilmer Arellano for pointing it out.

# %%
data.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=target, label="Age", figsize=(10,7),
    c=target, cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()
save_fig("age_scatterplot")
# Out:
# Saving figure age_scatterplot

# %%
data.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=data["mobile_money_classification"], label="mobile_money_classification", figsize=(10,7),
    c=data["mobile_money_classification"], cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()
save_fig("mobile_money_classification_scatterplot")
# Out:
# Saving figure mobile_money_classification_scatterplot

# %%
data.describe()
# Out:
#                 Q2           Q3           Q4           Q5           Q6  \
# count  5923.000000  5923.000000  5923.000000  5923.000000  5923.000000
# mean      1.563228     1.788452     3.048118     2.554618     1.838933
# std       0.496028     1.165322     1.550309     1.533433     0.367624
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     2.000000     1.000000     2.000000
# 50%       2.000000     1.000000     3.000000     3.000000     2.000000
# 75%       2.000000     3.000000     3.000000     4.000000     2.000000
# max       2.000000     4.000000     8.000000     6.000000     2.000000
#
#                 Q7         Q8_1         Q8_2         Q8_3         Q8_4  ...  \
# count  5923.000000  5923.000000  5923.000000  5923.000000  5923.000000  ...
# mean      1.397940     0.061287     0.631099     0.058754     0.336147  ...
# std       0.489514     0.239875     0.482548     0.235184     0.472430  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       1.000000     0.000000     1.000000     0.000000     0.000000  ...
# 75%       2.000000     0.000000     1.000000     0.000000     1.000000  ...
# max       2.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#                Q13          Q14          Q15          Q16          Q17  \
# count  5923.000000  5923.000000  5923.000000  5923.000000  5923.000000
# mean      0.402161     1.623502     0.755529     1.950025    -0.442175
# std       2.274109     0.484548     2.418967     1.577622     1.477339
# min      -1.000000     1.000000    -1.000000     1.000000    -1.000000
# 25%      -1.000000     1.000000    -1.000000     1.000000    -1.000000
# 50%      -1.000000     2.000000    -1.000000     1.000000    -1.000000
# 75%       2.000000     2.000000     3.000000     3.000000    -1.000000
# max       6.000000     2.000000     6.000000     5.000000     5.000000
#
#                Q18          Q19     Latitude    Longitude  \
# count  5923.000000  5923.000000  5923.000000  5923.000000
# mean      1.861219     3.171704    -6.015160    35.342245
# std       1.351193     1.311394     2.723232     2.912589
# min       1.000000     1.000000   -11.467463    29.639578
# 25%       1.000000     2.000000    -8.252787    32.922746
# 50%       1.000000     4.000000    -6.044494    35.031430
# 75%       4.000000     4.000000    -3.481024    38.385296
# max       5.000000     5.000000    -1.084000    40.258744
#
#        mobile_money_classification
# count                  5923.000000
# mean                      1.794867
# std                       1.196906
# min                       0.000000
# 25%                       1.000000
# 50%                       2.000000
# 75%                       3.000000
# max                       3.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Prepare the data for Machine Learning algorithms

# %% [markdown]
# Activity: write a function to spilt data into train and test set

# %%
def split_train_test(X, y,  test_ratio=0.2):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(X) * test_ratio)
    test_set = shuffled_indices[:test_set_size]
    train_set = shuffled_indices[test_set_size:]
    
    X_train, X_test = X.loc[train_set], X.loc[test_set]
    y_train, y_test = y.loc[train_set], y.loc[test_set]
    
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test(data, target)

# %%
print(f"Train ratio: {round(len(X_train)/len(data), 2)}; test raio: {np.round(len(X_test)/len(data), 2)}")
# Out:
# Train ratio: 0.8; test raio: 0.2

# %% [markdown]
# ## Select and train a model

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()

# %%
clf=lin_reg.fit(X_train, y_train)

# %% [markdown]
# ### Visualize and analyse predictions

# %% [markdown]
# Question: what metrics should we use to evaluate our model

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred_train = clf.predict(X_train)
y_pred_test  = clf.predict(X_test)

# %%
def get_results(pred_test, true_test, pred_train, true_train):
    
    mse_test = np.sqrt(mean_squared_error(true_test, pred_test))
    mse_train = np.sqrt(mean_squared_error(true_train, pred_train))
   
    #mcc=matthews_corrcoef(y_pred=pred, y_true=label)
    results=pd.DataFrame.from_dict({"Train":round(mse_train, 2), "Test":round(mse_test,2)}, orient='index', columns=["Results"])
    return results

# %%
get_results(y_pred_test, y_test, y_pred_train, y_train)
# Out:
#        Results
# Train    13.69
# Test     13.58

# %% [markdown]
# # Visualizing Predictions

# %% [markdown]
# Compare against the actual values:

# %%
plt.scatter(np.linspace(1,len(y_test.values[:10]),len(y_test.values[:10])), y_test.values[:10], color ='b',label="Actual", s=20)
plt.scatter(np.linspace(1,len(y_test.values[:10]),len(y_test.values[:10])), y_pred_test[:10], color ='g',label="Pred", s=20)
plt.legend(loc='best')
plt.title('Model Visualization')
plt.xlabel('Indexes')
plt.ylabel('Age Values')
# Out:
# Text(0, 0.5, 'Age Values')

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=10, random_state=42)
forest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
y_pred_train = forest_reg.predict(X_train)
y_pred_test = forest_reg.predict(X_test)

# %%
get_results(y_pred_test, y_test, y_pred_train, y_train)
# Out:
#        Results
# Train     5.05
# Test     12.52

# %%
plt.scatter(np.linspace(1,len(y_test.values[:10]),len(y_test.values[:10])), y_test.values[:10], color ='b',label="Actual", s=20)
plt.scatter(np.linspace(1,len(y_test.values[:10]),len(y_test.values[:10])), y_pred_test[:10], color ='g',label="Pred", s=20)
plt.legend(loc='best')
plt.title('Model Visualization')
plt.xlabel('Indexes')
plt.ylabel('Age Values')
# Out:
# Text(0, 0.5, 'Age Values')

# %% [markdown]
# ## Activity Try diffeent regression model and report your score

# %% [markdown]
# # Fine-tune your model

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
scores = cross_val_score(tree_reg, X_train, y_train,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [16.26157491 15.65274541 15.81479039 15.57694932 16.24853125 16.10553277
#  16.14308385 16.96994116 16.02858733 17.48572356]
# Mean: 16.2287459948487
# Standard deviation: 0.5586940032135871

# %%
lin_scores = cross_val_score(lin_reg, X_train, y_train,
                             scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [13.19087786 14.0131219  13.70077966 13.50672334 13.27602554 14.23711806
#  13.9025409  14.1967819  13.66872351 14.04242924]
# Mean: 13.773512189965505
# Standard deviation: 0.34854956122191166

# %% [markdown]
# **Note**: we specify `n_estimators=10` to avoid a warning about the fact that the default value is going to change to 100 in Scikit-Learn 0.22.

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=10, random_state=42)
forest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
rf_predictions = forest_reg.predict(X_test)
forest_mse = mean_squared_error(y_test, rf_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 12.52134697496909

# %%
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, X_train, y_train,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [11.65156406 12.30008404 11.65555227 11.47486705 11.89330024 12.69945429
#  12.95527115 12.95601289 12.39349394 12.1677849 ]
# Mean: 12.214738484891459
# Standard deviation: 0.5152528247755447

# %%
scores = cross_val_score(lin_reg, X_train, y_train, scoring="neg_mean_squared_error", cv=10)
pd.Series(np.sqrt(-scores)).describe()
# Out:
# count    10.000000
# mean     13.773512
# std       0.367403
# min      13.190878
# 25%      13.547223
# 50%      13.801660
# 75%      14.035102
# max      14.237118
# dtype: float64

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(X_train, y_train)
svm_predictions = svm_reg.predict(X_test)
svm_mse = mean_squared_error(y_test, svm_predictions)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# 13.77728701789928

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=42,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %% [markdown]
# The best hyperparameter combination found:

# %%
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=8, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=30,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %% [markdown]
# Let's look at the score of each hyperparameter combination tested during the grid search:

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 14.51155330230035 {'max_features': 2, 'n_estimators': 3}
# 12.861646148699531 {'max_features': 2, 'n_estimators': 10}
# 12.330010990519854 {'max_features': 2, 'n_estimators': 30}
# 13.975646595095238 {'max_features': 4, 'n_estimators': 3}
# 12.422580515755092 {'max_features': 4, 'n_estimators': 10}
# 11.91656592585207 {'max_features': 4, 'n_estimators': 30}
# 13.906894052502233 {'max_features': 6, 'n_estimators': 3}
# 12.30136193624062 {'max_features': 6, 'n_estimators': 10}
# 11.81093229319796 {'max_features': 6, 'n_estimators': 30}
# 13.568321236038516 {'max_features': 8, 'n_estimators': 3}
# 12.204807772784736 {'max_features': 8, 'n_estimators': 10}
# 11.78806260114667 {'max_features': 8, 'n_estimators': 30}
# 14.331317303269625 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 12.707242338597366 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 14.06486579020123 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 12.57202703164138 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 14.089279464588733 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 12.551239147426585 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.033807      0.011785         0.005401    2.333329e-03
# 1        0.080996      0.001671         0.007009    1.921683e-05
# 2        0.231206      0.004636         0.016409    5.020684e-04
# 3        0.033017      0.002604         0.004000    5.560829e-07
# 4        0.095203      0.002479         0.007599    4.895707e-04
# 5        0.274604      0.010025         0.015599    4.903107e-04
# 6        0.035807      0.001710         0.004000    1.409697e-06
# 7        0.112613      0.001341         0.007800    1.165002e-03
# 8        0.319392      0.007629         0.015609    4.981669e-04
# 9        0.040397      0.001835         0.004200    3.987553e-04
# 10       0.128002      0.003675         0.008000    1.095105e-03
# 11       0.365998      0.003171         0.015998    9.464947e-07
# 12       0.036398      0.001854         0.004209    3.948081e-04
# 13       0.117183      0.007304         0.008000    5.761645e-07
# 14       0.040215      0.001610         0.004001    1.451027e-06
# 15       0.124791      0.004357         0.007800    4.001173e-04
# 16       0.042589      0.001863         0.004000    8.064048e-07
# 17       0.137182      0.004504         0.008000    4.101908e-07
#
#    param_max_features param_n_estimators param_bootstrap  \
# 0                   2                  3             NaN
# 1                   2                 10             NaN
# 2                   2                 30             NaN
# 3                   4                  3             NaN
# 4                   4                 10             NaN
# 5                   4                 30             NaN
# 6                   6                  3             NaN
# 7                   6                 10             NaN
# 8                   6                 30             NaN
# 9                   8                  3             NaN
# 10                  8                 10             NaN
# 11                  8                 30             NaN
# 12                  2                  3           False
# 13                  2                 10           False
# 14                  3                  3           False
# 15                  3                 10           False
# 16                  4                  3           False
# 17                  4                 10           False
#
#                                                params  split0_test_score  \
# 0              {'max_features': 2, 'n_estimators': 3}        -187.829114
# 1             {'max_features': 2, 'n_estimators': 10}        -152.439757
# 2             {'max_features': 2, 'n_estimators': 30}        -145.591642
# 3              {'max_features': 4, 'n_estimators': 3}        -192.627754
# 4             {'max_features': 4, 'n_estimators': 10}        -153.595359
# 5             {'max_features': 4, 'n_estimators': 30}        -142.663206
# 6              {'max_features': 6, 'n_estimators': 3}        -191.289967
# 7             {'max_features': 6, 'n_estimators': 10}        -152.054188
# 8             {'max_features': 6, 'n_estimators': 30}        -142.125574
# 9              {'max_features': 8, 'n_estimators': 3}        -187.365917
# 10            {'max_features': 8, 'n_estimators': 10}        -146.327226
# 11            {'max_features': 8, 'n_estimators': 30}        -138.644203
# 12  {'bootstrap': False, 'max_features': 2, 'n_est...        -197.921120
# 13  {'bootstrap': False, 'max_features': 2, 'n_est...        -153.247461
# 14  {'bootstrap': False, 'max_features': 3, 'n_est...        -200.732771
# 15  {'bootstrap': False, 'max_features': 3, 'n_est...        -162.296118
# 16  {'bootstrap': False, 'max_features': 4, 'n_est...        -193.249883
# 17  {'bootstrap': False, 'max_features': 4, 'n_est...        -156.847437
#
#     split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0         -210.743319  ...      -210.585179       13.970301               18
# 1         -169.614747  ...      -165.421942        7.767959               11
# 2         -152.075573  ...      -152.029171        5.728560                6
# 3         -205.255717  ...      -195.318698        6.663936               14
# 4         -150.937037  ...      -154.320507        3.267502                7
# 5         -138.711061  ...      -142.004543        4.523600                3
# 6         -187.988279  ...      -193.401702        8.620146               13
# 7         -144.575053  ...      -151.323505        6.553471                5
# 8         -129.894092  ...      -139.498122        5.633751                2
# 9         -183.379630  ...      -184.099341        2.601427               12
# 10        -140.956656  ...      -148.957333        5.688268                4
# 11        -131.463209  ...      -138.958420        5.546815                1
# 12        -212.291374  ...      -205.386656        5.874315               17
# 13        -162.356511  ...      -161.474008        6.745087               10
# 14        -188.442921  ...      -197.820450        5.520504               15
# 15        -152.469848  ...      -158.055864        5.094258                9
# 16        -193.887014  ...      -198.507796        5.643838               16
# 17        -149.196129  ...      -157.533604        4.919920                8
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0           -52.529265          -54.294235          -56.425789
# 1           -29.943532          -30.535123          -31.529472
# 2           -23.329576          -24.181149          -23.522287
# 3           -47.050705          -54.368091          -50.212316
# 4           -27.541680          -28.146226          -28.756505
# 5           -22.045513          -22.133360          -22.301713
# 6           -48.658958          -47.418535          -48.219760
# 7           -26.676827          -26.948987          -28.162247
# 8           -21.470881          -21.519545          -21.528314
# 9           -46.923913          -47.403910          -44.439814
# 10          -26.076877          -26.684761          -27.093508
# 11          -20.983364          -21.724862          -21.374931
# 12           -0.040916           -0.069873           -0.000000
# 13           -0.014781           -0.115592           -0.011170
# 14           -0.000000           -0.000000           -0.000000
# 15           -0.001203           -0.009678           -0.000971
# 16           -0.051877           -0.000000           -0.000762
# 17           -0.006457           -0.004108           -0.002073
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0           -57.504059          -52.498242        -54.650318         2.027473
# 1           -31.186357          -30.652336        -30.769364         0.548126
# 2           -23.726862          -23.011703        -23.554315         0.392085
# 3           -49.884317          -49.936035        -50.290293         2.341784
# 4           -29.186085          -29.215390        -28.569177         0.643101
# 5           -22.147448          -21.742955        -22.074198         0.185026
# 6           -50.399689          -47.183222        -48.376033         1.143613
# 7           -27.151581          -27.166427        -27.221214         0.502764
# 8           -21.317943          -21.418975        -21.451131         0.077202
# 9           -44.661684          -45.913795        -45.868623         1.180761
# 10          -26.350914          -26.918286        -26.624869         0.370041
# 11          -21.050174          -21.100027        -21.246672         0.273702
# 12           -0.003678           -0.001465         -0.023186         0.027871
# 13           -0.012858           -0.001117         -0.031104         0.042507
# 14           -0.000000           -0.030298         -0.006060         0.012119
# 15           -0.013299           -0.006129         -0.006256         0.004791
# 16           -0.000762           -0.000000         -0.010680         0.020601
# 17           -0.004753           -0.001461         -0.003771         0.001817
#
# [18 rows x 23 columns]

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=200),
        'max_features': randint(low=1, high=8),
    }

forest_reg = RandomForestRegressor(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators='warn',
#                                                    n_jobs=None, oob_score=False,
#                                                    random_sta...
#                                                    warm_start=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001A81E815AC8>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001A81E815080>},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=0)

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 11.580457024622092 {'max_features': 7, 'n_estimators': 180}
# 12.216253032547629 {'max_features': 5, 'n_estimators': 15}
# 11.959298842513098 {'max_features': 3, 'n_estimators': 72}
# 12.041697518982414 {'max_features': 5, 'n_estimators': 21}
# 11.603449059798372 {'max_features': 7, 'n_estimators': 122}
# 11.958234826815628 {'max_features': 3, 'n_estimators': 75}
# 11.933555518315979 {'max_features': 3, 'n_estimators': 88}
# 11.747672958875205 {'max_features': 5, 'n_estimators': 100}
# 11.912822067314707 {'max_features': 3, 'n_estimators': 150}
# 15.022447506946596 {'max_features': 5, 'n_estimators': 2}

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances

# %%
final_model = grid_search.best_estimator_

final_predictions = final_model.predict(X_test)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse

# %% [markdown]
# We can compute a 95% confidence interval for the test RMSE:

# %%
from scipy import stats

# %%
confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
mean = squared_errors.mean()
m = len(squared_errors)

np.sqrt(stats.t.interval(confidence, m - 1,
                         loc=np.mean(squared_errors),
                         scale=stats.sem(squared_errors)))

# %% [markdown]
# We could compute the interval manually like this:

# %%
tscore = stats.t.ppf((1 + confidence) / 2, df=m - 1)
tmargin = tscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - tmargin), np.sqrt(mean + tmargin)

# %% [markdown]
# Alternatively, we could use a z-scores rather than t-scores:

# %%
zscore = stats.norm.ppf((1 + confidence) / 2)
zmargin = zscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - zmargin), np.sqrt(mean + zmargin)

# %% [markdown]
# # Visualizing Predictions

# %% [markdown]
# Lets take a look again at some few predictions compared to actual values

# %%
plt.scatter(np.linspace(1,len(y_test[0:10]),len(y_test[0:10])), y_test[0:10], color ='b',label="Actual", s=20)
plt.scatter(np.linspace(1,len(y_test[0:10]),len(y_test[0:10])), final_predictions[0:10], color = 'g', label="prediction", s=20)
plt.legend(loc='best')
plt.title('Model Visualization')
plt.xlabel('Indexes')
plt.ylabel('Age Values')

# %% [markdown]
# # Extra material

# %% [markdown]
# ## Model persistence using joblib

# %%
from sklearn.externals import joblib
joblib.dump(final_model, "my_model.pkl") # DIFF
#...
my_model_loaded = joblib.load("my_model.pkl") # DIFF

# %% [markdown]
# ## Example SciPy distributions for `RandomizedSearchCV`

# %%
from scipy.stats import geom, expon
geom_distrib=geom(0.5).rvs(10000, random_state=42)
expon_distrib=expon(scale=1).rvs(10000, random_state=42)
plt.hist(geom_distrib, bins=50)
plt.show()
plt.hist(expon_distrib, bins=50)
plt.show()

# %% [markdown]
# # Exercise With solutions

# %% [markdown]
# ## 1.

# %% [markdown]
# Question: Try a Support Vector Machine regressor (`sklearn.svm.SVR`), with various hyperparameters such as `kernel="linear"` (with various values for the `C` hyperparameter) or `kernel="rbf"` (with various values for the `C` and `gamma` hyperparameters). Don't worry about what these hyperparameters mean for now. How does the best `SVR` predictor perform?

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
        {'kernel': ['linear'], 'C': [10., 30., 100., 300., 1000., 3000., 10000., 30000.0]},
        {'kernel': ['rbf'], 'C': [1.0, 3.0, 10., 30., 100., 300., 1000.0],
         'gamma': [0.01, 0.03, 0.1, 0.3, 1.0, 3.0]},
    ]

svm_reg = SVR()
grid_search = GridSearchCV(svm_reg, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=2, n_jobs=4)
grid_search.fit(X_train, y_train)

# %% [markdown]
# The best model achieves the following score (evaluated using 5-fold cross validation):

# %%
negative_mse = grid_search.best_score_
rmse = np.sqrt(-negative_mse)
rmse

# %% [markdown]
# That's much worse than the `RandomForestRegressor`. Let's check the best hyperparameters found:

# %%
grid_search.best_params_

# %% [markdown]
# The linear kernel seems better than the RBF kernel. Notice that the value of `C` is the maximum tested value. When this happens you definitely want to launch the grid search again with higher values for `C` (removing the smallest values), because it is likely that higher values of `C` will be better.

# %% [markdown]
# ## 2.

# %% [markdown]
# Question: Try replacing `GridSearchCV` with `RandomizedSearchCV`.

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import expon, reciprocal

# see https://docs.scipy.org/doc/scipy/reference/stats.html
# for `expon()` and `reciprocal()` documentation and more probability distribution functions.

# Note: gamma is ignored when kernel is "linear"
param_distribs = {
        'kernel': ['linear', 'rbf'],
        'C': reciprocal(20, 200000),
        'gamma': expon(scale=1.0),
    }

svm_reg = SVR()
rnd_search = RandomizedSearchCV(svm_reg, param_distributions=param_distribs,
                                n_iter=50, cv=5, scoring='neg_mean_squared_error',
                                verbose=2, n_jobs=4, random_state=42)
rnd_search.fit(X_train, y_train)

# %% [markdown]
# The best model achieves the following score (evaluated using 5-fold cross validation):

# %%
negative_mse = rnd_search.best_score_
rmse = np.sqrt(-negative_mse)
rmse

# %% [markdown]
# Now this is much closer to the performance of the `RandomForestRegressor` (but not quite there yet). Let's check the best hyperparameters found:

# %%
rnd_search.best_params_

# %% [markdown]
# This time the search found a good set of hyperparameters for the RBF kernel. Randomized search tends to find better hyperparameters than grid search in the same amount of time.

# %% [markdown]
# Let's look at the exponential distribution we used, with `scale=1.0`. Note that some samples are much larger or smaller than 1.0, but when you look at the log of the distribution, you can see that most values are actually concentrated roughly in the range of exp(-2) to exp(+2), which is about 0.1 to 7.4.

# %%
expon_distrib = expon(scale=1.)
samples = expon_distrib.rvs(10000, random_state=42)
plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.title("Exponential distribution (scale=1.0)")
plt.hist(samples, bins=50)
plt.subplot(122)
plt.title("Log of this distribution")
plt.hist(np.log(samples), bins=50)
plt.show()

# %% [markdown]
# The distribution we used for `C` looks quite different: the scale of the samples is picked from a uniform distribution within a given range, which is why the right graph, which represents the log of the samples, looks roughly constant. This distribution is useful when you don't have a clue of what the target scale is:

# %%
reciprocal_distrib = reciprocal(20, 200000)
samples = reciprocal_distrib.rvs(10000, random_state=42)
plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.title("Reciprocal distribution (scale=1.0)")
plt.hist(samples, bins=50)
plt.subplot(122)
plt.title("Log of this distribution")
plt.hist(np.log(samples), bins=50)
plt.show()

# %% [markdown]
# The reciprocal distribution is useful when you have no idea what the scale of the hyperparameter should be (indeed, as you can see on the figure on the right, all scales are equally likely, within the given range), whereas the exponential distribution is best when you know (more or less) what the scale of the hyperparameter should be.

# %% [markdown]
# ## 3.

# %% [markdown]
# Question: Try adding a transformer in the preparation pipeline to select only the most important attributes.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

def indices_of_top_k(arr, k):
    return np.sort(np.argpartition(np.array(arr), -k)[-k:])

class TopFeatureSelector(BaseEstimator, TransformerMixin):
    def __init__(self, feature_importances, k):
        self.feature_importances = feature_importances
        self.k = k
    def fit(self, X, y=None):
        self.feature_indices_ = indices_of_top_k(self.feature_importances, self.k)
        return self
    def transform(self, X):
        return X[:, self.feature_indices_]

# %% [markdown]
# Note: this feature selector assumes that you have already computed the feature importances somehow (for example using a `RandomForestRegressor`). You may be tempted to compute them directly in the `TopFeatureSelector`'s `fit()` method, however this would likely slow down grid/randomized search since the feature importances would have to be computed for every hyperparameter combination (unless you implement some sort of cache).

# %% [markdown]
# Let's define the number of top features we want to keep:

# %%
k = 5

# %% [markdown]
# Now let's look for the indices of the top k features:

# %%
top_k_feature_indices = indices_of_top_k(feature_importances, k)
top_k_feature_indices

# %%
np.array(attributes)[top_k_feature_indices]

# %% [markdown]
# Let's double check that these are indeed the top k features:

# %%
sorted(zip(feature_importances, attributes), reverse=True)[:k]

# %% [markdown]
# Looking good... Now let's create a new pipeline that runs the previously defined preparation pipeline, and adds top k feature selection:

# %%
preparation_and_feature_selection_pipeline = Pipeline([
    ('preparation', full_pipeline),
    ('feature_selection', TopFeatureSelector(feature_importances, k))
])

# %%
data_top_k_features = preparation_and_feature_selection_pipeline.fit_transform(train_set_features)

# %% [markdown]
# Let's look at the features of the first 3 instances:

# %%
data_top_k_features[0:3]

# %% [markdown]
# Now let's double check that these are indeed the top k features:

# %%
data[0:3, top_k_feature_indices]

# %% [markdown]
# Works great!  :)

# %% [markdown]
# ## 4.

# %% [markdown]
# Question: Try creating a single pipeline that does the full data preparation plus the final prediction.

# %%
prepare_select_and_predict_pipeline = Pipeline([
    ('preparation', full_pipeline),
    ('feature_selection', TopFeatureSelector(feature_importances, k)),
    ('svm_reg', SVR(**rnd_search.best_params_))
])

# %%
prepare_select_and_predict_pipeline.fit(train_set_features, train_set_labels)

# %% [markdown]
# Let's try the full pipeline on a few instances:

# %%
some_data = X_train.iloc[:4]
some_labels = y_test.iloc[:4]

print("Predictions:\t", prepare_select_and_predict_pipeline.predict(some_data))
print("Labels:\t\t", list(some_labels))

# %% [markdown]
# Well, the full pipeline seems to work fine. Of course, the predictions are not fantastic: they would be better if we used the best `RandomForestRegressor` that we found earlier, rather than the best `SVR`.

# %% [markdown]
# ## 5.

# %% [markdown]
# Question: Automatically explore some preparation options using `GridSearchCV`.

# %%
param_grid = [{
    'preparation__num__imputer__strategy': ['mean', 'median', 'most_frequent'],
    'feature_selection__k': list(range(1, len(feature_importances) + 1))
}]

grid_search_prep = GridSearchCV(prepare_select_and_predict_pipeline, param_grid, cv=5,
                                scoring='neg_mean_squared_error', verbose=2, n_jobs=4)
grid_search_prep.fit(X_train, y_train)

# %%
grid_search_prep.best_params_

# %% [markdown]
# The best imputer strategy is `most_frequent` and apparently almost all features are useful (15 out of 16). The last one (`ISLAND`) seems to just add some noise.

# %% [markdown]
# Congratulations! You already know quite a lot about Machine Learning. :)
